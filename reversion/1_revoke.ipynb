# %% [markdown]
# ## # Rol de DataEngineers

# %%
# %sql
-- CATALOGO
REVOKE ALL PRIVILEGES ON CATALOG proyecto_olist FROM `DataEngineers`;

-- PERMISOS ESQUEMAS
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyecto_olist.bronze FROM `DataEngineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyecto_olist.silver FROM `DataEngineers`;
REVOKE CREATE, USE SCHEMA ON SCHEMA  proyecto_olist.golden FROM `DataEngineers`;

-- PERMISOS CREACION TABLAS
REVOKE CREATE TABLE ON SCHEMA proyecto_olist.bronze FROM `DataEngineers`;
REVOKE CREATE TABLE ON SCHEMA proyecto_olist.silver FROM `DataEngineers`;
REVOKE CREATE TABLE ON SCHEMA proyecto_olist.golden FROM `DataEngineers`;

-- PERMISOS MODIFICACION TABLAS
REVOKE MODIFY ON SCHEMA proyecto_olist.bronze FROM `DataEngineers`;
REVOKE MODIFY ON SCHEMA proyecto_olist.silver FROM `DataEngineers`;
REVOKE MODIFY ON SCHEMA proyecto_olist.golden FROM `DataEngineers`;

--PERMISOS TABLAS
REVOKE SELECT ON TABLE proyecto_olist.bronze.orders FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.customers FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.products FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.order_items FROM `DataEngineers`;

REVOKE SELECT ON TABLE proyecto_olist.silver.orders FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.silver.customers FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.silver.products FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.silver.order_items FROM `DataEngineers`;

REVOKE SELECT ON TABLE proyecto_olist.golden.dim_customers FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.golden.dim_products FROM `DataEngineers`;
REVOKE SELECT ON TABLE proyecto_olist.golden.fact_orders FROM `DataEngineers`;

# %%
# %sql
-- PERMISOS EXTERNAL LOCATION
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-catalog-mt` FROM `DataEngineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` FROM `DataEngineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` FROM `DataEngineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` FROM `DataEngineers`;
REVOKE READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` FROM `DataEngineers`;

# %% [markdown]
# ## Rol de DataScientist

# %%
# %sql
-- CATALOGO
REVOKE USE CATALOG ON CATALOG proyecto_olist FROM `DataScientist`;

-- PERMISOS ESQUEMAS
REVOKE USE SCHEMA ON SCHEMA proyecto_olist.bronze FROM `DataScientist`;
REVOKE USE SCHEMA ON SCHEMA proyecto_olist.silver FROM `DataScientist`;
REVOKE USE SCHEMA ON SCHEMA proyecto_olist.golden FROM `DataScientist`;

-- PERMISOS TABLAS
REVOKE SELECT ON TABLE proyecto_olist.bronze.orders FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.customers FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.products FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.bronze.order_items FROM `DataScientist`;

REVOKE SELECT ON TABLE proyecto_olist.silver.orders FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.silver.customers FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.silver.products FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.silver.order_items FROM `DataScientist`;

REVOKE SELECT ON TABLE proyecto_olist.golden.dim_customers FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.golden.dim_products FROM `DataScientist`;
REVOKE SELECT ON TABLE proyecto_olist.golden.fact_orders FROM `DataScientist`;

# %%
# %sql
-- PERMISOS EXTERNAL LOCATION
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-catalog-mt` FROM `DataScientist`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-bronze` FROM `DataScientist`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-silver` FROM `DataScientist`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-golden` FROM `DataScientist`;
REVOKE READ FILES ON EXTERNAL LOCATION `exlt-raw` FROM `DataScientist`;

# %% [markdown]
# ## Rol de DataAnalyst

# %%
# %sql
-- CATALOGO
REVOKE USE CATALOG ON CATALOG proyecto_olist FROM `DataAnalyst`;

-- PERMISOS ESQUEMAS
REVOKE USE SCHEMA ON SCHEMA proyecto_olist.golden FROM `DataAnalyst`;

-- PERMISOS TABLAS
REVOKE SELECT ON TABLE proyecto_olist.golden.dim_customers FROM `DataAnalyst`;
REVOKE SELECT ON TABLE proyecto_olist.golden.dim_products FROM `DataAnalyst`;
REVOKE SELECT ON TABLE proyecto_olist.golden.fact_orders FROM `DataAnalyst`;
